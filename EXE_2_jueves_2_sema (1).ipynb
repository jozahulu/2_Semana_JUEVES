# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N=1000 # Numero de Datos

# %%
l =  np.random.rand(2,N)
#------
a_2 = [random.uniform(1,3) for x in range(N)]    # definienddo el conjuntto de posiciones en un determinado momento
a_1 = [random.uniform(-2,0) for x in range(N)]
#------
b_2 = [random.uniform(-1,1) for x in range(N)]
b_1 = [random.uniform(-1.5,0.5) for x in range(N)]
#-----------
c_2 = [random.uniform(0,-2) for x in range(N)]
c_1 = [random.uniform(0.5,2.5) for x in range(N)]
##-------
d_2 = [random.uniform(3,5) for x in range(N)]
d_1 = [random.uniform(-1.5,0.5) for x in range(N)]
####-----
e_2 = [random.uniform(4,6) for x in range(N)]
e_1 = [random.uniform(0.5,2.5) for x in range(N)]
##-----
f_2 = [random.uniform(3.5,5.5) for x in range(N)]
f_1 = [random.uniform(2.5,4.5) for x in range(N)]
####-----
g_2 = [random.uniform(3.5,5.5) for x in range(N)]
g_1 = [random.uniform(4.5,6.5) for x in range(N)]
####-----
####-----
h_2 = [random.uniform(1.5,3.5) for x in range(N)]
h_1 = [random.uniform(3.8,5.8) for x in range(N)]
####-----
####-----
x_2 = [random.uniform(-0.5,1.5) for x in range(N)]
x_1 = [random.uniform(3.5,5.5) for x in range(N)]
####-----
####-----
y_2 = [random.uniform(-2,0) for x in range(N)]
y_1 = [random.uniform(2.5,3.5) for x in range(N)]
####-----
z_2 = [random.uniform(-1.5,-0.5) for x in range(N)]
z_1 = [random.uniform(3.5,5.5) for x in range(N)]
####-----
l_2 = [random.uniform(-2,0) for x in range(N)]
l_1 = [random.uniform(2.5,3.5) for x in range(N)]

# %%
plt.plot(z_1,z_2,'.')  # Graficando el conjunto de puntos aleatorios en el plano
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
circle_r = 4
circle_x = 2
circle_y = 2

#N = 1000

phi = 2 * np.pi * np.random.rand(N)
r = circle_r * np.random.rand(N)

# %%
ranillo = 2*np.pi*np.random.uniform(1,2,N)    # Determinan los dististon espaciamientos en el plano
rani = np.sqrt(ranillo)#**(0.5)
x = rani * np.cos(phi) + circle_x
y = rani * np.sin(phi) + circle_y
plt.plot(x,y,'.',color='red')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0,0.5,'y')

# %%
plt.title('Distintos movimientos')

plt.plot(a_1,a_2,'.')   #Graficas de las distintas posiciones en 
plt.plot(b_1,b_2,'.',color='red')
plt.plot(c_1,c_2,'.',color='green')
plt.plot(d_1,d_2,'.',color='green')
plt.plot(e_1,e_2,'.',color='blue')
plt.plot(f_1,f_2,'.',color='magenta')
plt.plot(g_1,g_2,'.',color='blue')
plt.plot(h_1,h_2,'.',color='green')
plt.plot(x_1,x_2,'.',color='red')
plt.plot(y_1,y_2,'.',color='magenta')
plt.plot(z_1,z_2,'.',color='blue')
plt.plot(x,y,'.')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
def distancia(x1,x2,y1,y2):         #Distancia en el x,y
    d = np.sqrt((x2 - x1)**2 + (y2-y1)**2)
    return d

# %%
def dist_x(x1,x2):   #Distancia solo para X 
    d_x = np.sqrt((x2 - x1)**2 )
    return d_x

# %%
def dist_y(y1,y2):  #Distancia solo para y
    d_y = np.sqrt((y2-y1)**2)
    return d_y

# %%
def punto(x,y,v):  #Distancia solo para y
    p= x*y+v
    return p

# %%
dtot = N*(N-1)/2
j = 0

#####----------1
d_x_1 = []  ;  dx_1 = []   ;r_1=[]  ;
r_r_1=[]
d_d_1=[]
d_r_1=[]
d_y_1 = []  ;  dy_1 = []   ;r=[]
#####----------2
d_x_2 = []  ;  dx_2 = []   ;r_2=[]
r_r_2=[]
d_d_2=[]
d_r_2=[]
d_y_2 = []  ;  dy_2 = []
####-------------3
d_x_3 = []  ;  dx_3 = []   ;r_3=[]
r_r_3=[]
d_d_3=[]
d_r_3=[]
d_y_3 = []  ;  dy_3 = []
####-------------4
d_x_4 = []  ;  dx_4 = []   ;r_4=[]
r_r_4=[]
d_d_4=[]
d_r_4=[]
d_y_4 = []  ;  dy_4 = []
####-------------5
d_x_5 = []  ;  dx_5=  []  ;r_5=[]
r_r_5=[]
d_d_5=[]
d_r_5=[]
d_y_5 = []  ;  dy_5 = []
####-------------6
d_x_6 = []  ;  dx_6 = []  ;r_6=[]
r_r_6=[]
d_d_6=[]
d_r_6=[]
d_y_6 = []  ;  dy_6 = []
####-------------7
d_x_7 = []  ;  dx_7 = []  ;r_7=[]
r_r_7=[]
d_d_7=[]
d_r_7=[]
d_y_7 = []  ;  dy_7 = []
####-------------8
d_x_8 = []  ;  dx_8 = []  ;r_8=[]
r_r_8=[]
d_d_8=[]
d_r_8=[]
d_y_8 = []  ;  dy_8 = []
####-------------9
d_x_9 = []  ;  dx_9 = []  ;r_9=[]
r_r_9=[]
d_d_9=[]
d_r_9=[]
d_y_9 = []  ;  dy_9 = []
####-------------10
d_x_10 = []  ;  dx_10 = []  ;r_10=[]
r_r_10=[]
d_d_10=[]
d_r_10=[]
d_y_10 = []  ;  dy_10 = []
####-------------11
d_x_11 = []  ;  dx_11 = []  ;r_11=[]
r_r_11=[]
d_d_11=[]
d_r_11=[]
d_y_11 = []  ;  dy_11 = []

# %%
####-----1
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],a_1[j])
        d_a = dist_y(y[i],a_2[j])
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],a_1[j],y[i],a_2[i])
        d_x_1.append(d_d)
        d_y_1.append(d_a)
        r_r_1.append( r_r)
        d_d_1.append( d_d)
        d_r_1.append(d_r)
dx_1=sort(d_x_1)  # Ordena de menor a mayor los parametros del vecto
dy_1=sort(d_y_1)
#print(dx_1)
print(dx_1[0]) # Distancia mas cercana para x   
print(dy_1[0]) # Distancia mas cercana para y
v=0.1*(dx_1[0]*dx_1[0]+dy_1[0]*dy_1[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_1[i],dy_1[i],v)
    r_1.append(r)        # Representa el producto punto de la funcion
#print(r_1)
# Out:
# 0.0
# 4.493528968474436e-06
# 4.4935289684744366e-07

# %%
####-----2
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],b_1[j])
        d_a = dist_y(y[i],b_2[j])
        d_x_2.append(d_d)
        d_y_2.append(d_a)
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],b_1[j],y[i],b_2[i])
        r_r_2.append( r_r)
        d_d_2.append( d_d)
        d_r_2.append(d_r)
dx_2=sort(d_x_2)  # Ordena de menor a mayor los parametros del vecto
dy_2=sort(d_y_2)
#print(dx_2)
print(dx_2[0]) # Distancia mas cercana para x   
print(dy_2[0]) # Distancia mas cercana para y
v=0.1*(dx_2[0]*dx_2[0]+dy_2[0]*dy_2[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_2[i],dy_2[i],v)
    r_1.append(r)        # Representa el producto punto de la funcion
#print(r_2)
# Out:
# 1.4717473819647608e-06
# 1.7145515898153718e-06
# 2.259585694426867e-07

# %%
####-----3
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],c_1[j])
        d_a = dist_y(y[i],c_2[j])
        d_x_3.append(d_d)
        d_y_3.append(d_a)
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],c_1[j],y[i],c_2[i])
        r_r_3.append( r_r)
        d_d_3.append( d_d)
        d_r_3.append(d_r)
dx_3=sort(d_x_3)  # Ordena de menor a mayor los parametros del vecto
dy_3=sort(d_y_3)
#print(dx_3)
print(dx_3[0]) # Distancia mas cercana para x   
print(dy_3[0]) # Distancia mas cercana para y
v=0.1*(dx_3[0]*dx_3[0]+dy_3[0]*dy_3[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_3[i],dy_3[i],v)
    r_3.append(r)        # Representa el producto punto de la funcion
#print(r_1)
# Out:
# 7.2435476941024035e-06
# 3.0343906218810446e-06
# 7.853439351194856e-07

# %%
####-----4
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],d_1[j])
        d_a = dist_y(y[i],d_2[j])
        d_x_4.append(d_d)
        d_y_4.append(d_a)
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],d_1[j],y[i],d_2[i])
        r_r_4.append( r_r)
        d_d_4.append( d_d)
        d_r_4.append(d_r)
dx_4=sort(d_x_4)  # Ordena de menor a mayor los parametros del vecto
dy_4=sort(d_y_4)
#print(dx_4)
print(dx_4[0]) # Distancia mas cercana para x   
print(dy_4[0]) # Distancia mas cercana para y
v=0.1*(dx_4[0]*dx_4[0]+dy_4[0]*dy_4[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_4[i],dy_4[i],v)
    r_4.append(r)        # Representa el producto punto de la funcion
#print(r_r_4)
# Out:
# 7.587152124344243e-06
# 4.328886858750991e-06
# 8.735224026538094e-07

# %%
####-----5
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],e_1[j])
        d_a = dist_y(y[i],e_2[j])
        d_x_5.append(d_d)
        d_y_5.append(d_a)
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],e_1[j],y[i],e_2[i])
        r_r_5.append( r_r)
        d_d_5.append( d_d)
        d_r_5.append(d_r)
dx_5=sort(d_x_5)  # Ordena de menor a mayor los parametros del vecto
dy_5=sort(d_y_5)
print(dx_5)
print(dx_5[0]) # Distancia mas cercana para x   
print(dy_5[0]) # Distancia mas cercana para y
v=0.1*(dx_5[0]*dx_5[0]+dy_5[0]*dy_5[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_5[i],dy_5[i],v)
    r_5.append(r)        # Representa el producto punto de la funcion
#print(r_5)
# Out:
# [5.17247544e-06 1.23668973e-05 1.31805752e-05 ... 5.02931188e+00
#  5.03009913e+00 5.03080725e+00]
# 5.172475437298374e-06
# 4.4845051911934775e-06
# 6.845822737939995e-07

# %%
####-----6
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],f_1[j])
        d_a = dist_y(y[i],f_2[j])
        d_x_6.append(d_d)
        d_y_6.append(d_a)
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],f_1[j],y[i],f_2[i])
        r_r_6.append( r_r)
        d_d_6.append( d_d)
        d_r_6.append(d_r)
dx_6=sort(d_x_6)  # Ordena de menor a mayor los parametros del vecto
dy_6=sort(d_y_6)
#print(dx_6)
print(dx_6[0]) # Distancia mas cercana para x   
print(dy_6[0]) # Distancia mas cercana para y
v=0.1*(dx_6[0]*dx_6[0]+dy_6[0]*dy_6[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_6[i],dy_6[i],v)
    r_6.append(r)        # Representa el producto punto de la funcion
#print(r_6)
# Out:
# 1.0561056722480089e-06
# 3.157638801098983e-06
# 3.3295708415890846e-07

# %%
####-----7
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],g_1[j])
        d_a = dist_y(y[i],g_2[j])
        d_x_7.append(d_d)
        d_y_7.append(d_a)
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],g_1[j],y[i],g_2[i])
        r_r_7.append( r_r)
        d_d_7.append( d_d)
        d_r_7.append(d_r)
dx_7=sort(d_x_7)  # Ordena de menor a mayor los parametros del vecto
dy_7=sort(d_y_7)
#print(dx_7)
print(dx_7[0]) # Distancia mas cercana para x   
print(dy_7[0]) # Distancia mas cercana para y
v=0.1*(dx_7[0]*dx_7[0]+dy_7[0]*dy_7[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_7[i],dy_7[i],v)
    r_7.append(r)        # Representa el producto punto de la funcion
#print(r_7)
# Out:
# 4.226552658082028e-06
# 1.1001057300674688e-06
# 4.367376785768264e-07

# %%
####-----8
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],h_1[j])
        d_a = dist_y(y[i],h_2[j])
        d_x_8.append(d_d)
        d_y_8.append(d_a)
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],h_1[j],y[i],h_2[i])
        r_r_8.append( r_r)
        d_d_8.append( d_d)
        d_r_8.append(d_r)
dx_8=sort(d_x_8)  # Ordena de menor a mayor los parametros del vecto
dy_8=sort(d_y_8)
#print(dx_8)
print(dx_8[0]) # Distancia mas cercana para x   
print(dy_8[0]) # Distancia mas cercana para y
v=0.1*(dx_8[0]*dx_8[0]+dy_8[0]*dy_8[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_8[i],dy_8[i],v)
    r_8.append(r)        # Representa el producto punto de la funcion
#print(r_8)
# Out:
# 8.920933571410217e-06
# 4.4363260043311925e-06
# 9.963134255956757e-07

# %%
#--------9
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],x_1[j])
        d_a = dist_y(y[i],x_2[j])
        d_x_9.append(d_d)
        d_y_9.append(d_a)
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],x_1[j],y[i],x_2[i])
        r_r_9.append( r_r)
        d_d_9.append( d_d)
        d_r_9.append(d_r)
dx_9=sort(d_x_9)  # Ordena de menor a mayor los parametros del vecto
dy_9=sort(d_y_9)
#print(dx_9)
print(dx_9[0]) # Distancia mas cercana para x   
print(dy_9[0]) # Distancia mas cercana para y
v=0.1*(dx_9[0]*dx_9[0]+dy_9[0]*dy_9[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_9[i],dy_9[i],v)
    r_9.append(r)        # Representa el producto punto de la funcion
#print(r_9)
# Out:
# 4.3367738289390445e-07
# 5.853358582275092e-07
# 7.28487569805169e-08

# %%
#--------------10
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],y_1[j])
        d_a = dist_y(y[i],y_2[j])
        d_x_10.append(d_d)
        d_y_10.append(d_a)
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],y_1[j],y[i],y_2[i])
        r_r_10.append( r_r)
        d_d_10.append( d_d)
        d_r_10.append(d_r)
dx_10=sort(d_x_10)  # Ordena de menor a mayor los parametros del vecto
dy_10=sort(d_y_10)
print(dx_10)
print(dx_10[0]) # Distancia mas cercana para x   
print(dy_10[0]) # Distancia mas cercana para y
v=0.1*(dx_10[0]*dx_10[0]+dy_10[0]*dy_10[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_10[i],dy_10[i],v)
    r_10.append(r)        # Representa el producto punto de la funcion
#print(r_10)

# %%
###------------11
for i in range(N):
    for j in range(N):
        d_d = dist_x(x[i],z_1[j])
        d_a = dist_y(y[i],z_2[j])
        d_x_11.append(d_d)
        d_y_11.append(d_a)
        ####__________
        r_r = distancia(x[i],x[j],y[i],y[i])
        d_d = distancia(x[i],x[j],y[i],y[i])
        d_r = distancia(x[i],z_1[j],y[i],z_2[i])
        r_r_11.append( r_r)
        d_d_11.append( d_d)
        d_r_11.append(d_r)
dx_11=sort(d_x_11)  # Ordena de menor a mayor los parametros del vecto
dy_11=sort(d_y_11)
#print(dx_11)
print(dx_11[0]) # Distancia mas cercana para x   
print(dy_11[0]) # Distancia mas cercana para y
v=0.1*(dx_11[0]*dx_11[0]+dy_11[0]*dy_11[0])**0.5
print(v) # Valor de la velocidad
for i in range(N*N):
    r=punto(dx_11[i],dy_11[i],v)
    r_11.append(r)        # Representa el producto punto de la funcion
#print(r_11)
# Out:
# 1.7513935928192836e-06
# 7.532374051155699e-07
# 1.906501011128417e-07

# %%
rr=r_r_1+r_r_2+r_r_3+r_r_4+r_r_5+r_r_6+r_r_7+r_r_8+r_r_9+r_r_10+r_r_11
dr=d_r_1+d_r_2+d_r_3+d_r_4+d_r_5+d_r_6+d_r_7+d_r_8+d_r_9+d_r_10+d_r_11
dd=d_d_1+d_d_2+d_d_3+d_d_4+d_d_5+d_d_6+d_d_7+d_d_8+d_d_9+d_d_10+d_d_11

# %%
data_n, data_bin,m = plt.hist(rr,bins=20,color='red')
print(data_n)
print(data_bin)
print(len(data_bin))
# Out:
# [108558.  98444.  84496.  72856.  65428.  59248.  54248.  49642.  48410.
#   48992.  48272.  47670.  45604.  44172.  41732.  35276.  25710.  14432.
#    5546.   1264.]
# [0.         0.35350209 0.70700418 1.06050626 1.41400835 1.76751044
#  2.12101253 2.47451461 2.8280167  3.18151879 3.53502088 3.88852297
#  4.24202505 4.59552714 4.94902923 5.30253132 5.6560334  6.00953549
#  6.36303758 6.71653967 7.07004176]
# 21

# %%
ran_n, ran_bin, p = plt.hist(d_d_1,bins=20,color='green')

# %%
da_n, da_bin, q = plt.hist(d_r_1,bins=20, label='$DR(r)$')
print(len(da_n))
plt.legend()
# Out:
# 20

# %%
plt.plot(data_bin[1:],(data_n*ran_n)/(da_n)**2,label=('$\dfrac{DD(r)RR(r)}{DR(r)^2}$'))
plt.legend()

# %%
plt.plot(data_bin[1:],(data_n*ran_n)/(da_n)**2,label=('$\dfrac{DD(r)RR(r)}{DR(r)^2}$'))
plt.legend()

# %%
plt.plot(data_bin[1:],1.+ data_n/ran_n -2*da_n/ran_n, label=('Landy-Szalay=$1+\dfrac{DD(r)}{RR(r)}-2\dfrac{DR(r)}{RR(r)}$'))
